# %%
import pandas as pd
import sklearn

# %% [markdown]
# ## Sales Win Loss Data by IBM
# download here: https://www.ibm.com/communities/analytics/watson-analytics-blog/sales-win-loss-sample-dataset/

# %%
data = pd.read_csv('../datasets/WA_Fn-UseC_-Sales-Win-Loss.csv')

# %%
data.head()
# Out:
#    Opportunity Number Supplies Subgroup Supplies Group     Region  \
# 0             1641984       Accessories            Car  Northwest
# 1             1658010       Accessories            Car    Pacific
# 2             1674737  Motorcycle Parts       Non-auto    Pacific
# 3             1675224          Shelters       Non-auto    Midwest
# 4             1689785       Accessories            Car    Pacific
#
#   Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0    Fields Sales                           76                Won
# 1        Reseller                           63               Loss
# 2        Reseller                           24                Won
# 3        Reseller                           16               Loss
# 4        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# ...

# %%
data.head(10)
# Out:
#    Opportunity Number Supplies Subgroup Supplies Group     Region  \
# 0             1641984       Accessories            Car  Northwest
# 1             1658010       Accessories            Car    Pacific
# 2             1674737  Motorcycle Parts       Non-auto    Pacific
# 3             1675224          Shelters       Non-auto    Midwest
# 4             1689785       Accessories            Car    Pacific
# 5             1692390          Shelters       Non-auto    Pacific
# 6             1935837          Car Care            Car    Pacific
# 7             1952571       Accessories            Car    Pacific
# 8             1999486         Batteries            Car  Northwest
# 9             2052337       Accessories            Car    Pacific
#
#   Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0    Fields Sales                           76                Won
# 1        Reseller                           63               Loss
# ...

# %%
data.tail()
# Out:
#        Opportunity Number    Supplies Subgroup Supplies Group        Region  \
# 78020            10089932            Batteries            Car     Southeast
# 78021            10089961             Shelters       Non-auto     Northeast
# 78022            10090145          Accessories            Car     Southeast
# 78023            10090430          Accessories            Car     Southeast
# 78024            10094255  InteriorAccessories            Car  Mid-Atlantic
#
#       Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 78020        Reseller                            0               Loss
# 78021        Reseller                            0                Won
# 78022        Reseller                            0               Loss
# 78023    Fields Sales                            0               Loss
# 78024        Reseller                            0               Loss
#
#        Sales Stage Change Count  Total Days Identified Through Closing  \
# ...
